# %%
#!pip install contextily
#!pip install osmnx
#!pip install palettable

# %%
from fonctions import *

# %% [markdown]
# ## Looking at restaurants only

# %%
get_place("Gare du Nord").head()
# Out:
# /home/onyxia/work/BATO-MOUCHE-Stat-App/fonctions.py:37: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   gdf_pois["center"]=gdf_pois.centroid
#                            amenity               name  \
# element_type osmid
# node         251851390  restaurant       Le Royal Est
#              251851391  restaurant  Bouillon Chartier
#              294039723        cafe     Café des Dames
#              294162536   fast_food         McDonald's
#              304964997  restaurant   La P'tite Louise
#
#                                             opening_hours       source  \
# element_type osmid
# node         251851390  Mo-Sa 06:00-02:00, Su 07:00-02:00  survey 2017
#              251851391                                NaN          NaN
#              294039723                                NaN          NaN
# ...

# %%
count_amenities("Gare du Nord")
# Out:
# /home/onyxia/work/BATO-MOUCHE-Stat-App/fonctions.py:37: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   gdf_pois["center"]=gdf_pois.centroid
#       amenity how many
# 0  restaurant    546.0
# 1        cafe    134.0
# 2         bar     83.0
# 3   ice_cream      2.0
# 4   fast_food    182.0
# 5         pub     29.0
# 6  food_court      0.0
# 7  biergarten      0.0
# 8       total    976.0

# %%
places = ["Gare du Nord", "Tour Eiffel", "Place de la Bastille", 
          "Arc de triomphe", "Parc des buttes Chaumont", "Palais de la porte dorée", "Westfield Forum des Halles", "Porte de la Chapelle", "Opéra Garnier", "Sacré Coeur"]

for i in tqdm(range(len(places))) : 
    print(places[i])
    print(count_amenities(places[i]))
    print(' ')
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Gare du Nord
# /home/onyxia/work/BATO-MOUCHE-Stat-App/fonctions.py:37: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   gdf_pois["center"]=gdf_pois.centroid
#       amenity how many
# 0  restaurant    546.0
# 1        cafe    134.0
# 2         bar     83.0
# 3   ice_cream      2.0
# 4   fast_food    182.0
# 5         pub     29.0
# 6  food_court      0.0
# 7  biergarten      0.0
# 8       total    976.0
#
# Tour Eiffel
# /home/onyxia/work/BATO-MOUCHE-Stat-App/fonctions.py:37: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   gdf_pois["center"]=gdf_pois.centroid
#       amenity how many
# 0  restaurant    223.0
# 1        cafe     59.0
# 2         bar     10.0
# ...

# %% [markdown]
# ## Looking at restaurants, culture and education

# %%
get_place2("Tour Eiffel")
# Out:
# /home/onyxia/work/BATO-MOUCHE-Stat-App/fonctions.py:91: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   gdf_pois["center"]=gdf_pois.centroid
#                               amenity              brewery contact:city  \
# element_type osmid
# node         252958952            pub  Frog Natural Blonde        Paris
#              254494167     restaurant                  NaN          NaN
#              254497766     restaurant                  NaN          NaN
#              255060753     restaurant                  NaN          NaN
#              308684349           cafe                  NaN          NaN
# ...                               ...                  ...          ...
# way          308145239     restaurant                  NaN          NaN
#              641198244     restaurant                  NaN          NaN
# ...

# %%
count_amenities2("Tour Eiffel")
# Out:
# /home/onyxia/work/BATO-MOUCHE-Stat-App/fonctions.py:91: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   gdf_pois["center"]=gdf_pois.centroid
#            amenity how many
# 0       restaurant    326.0
# 1  culture and art     16.0
# 2        education     70.0
# 3            total    412.0

# %%
places = ["Gare du Nord", "Tour Eiffel", "Place de la Bastille", 
          "Arc de triomphe", "Parc des buttes Chaumont", "Palais de la porte dorée", "Westfield Forum des Halles", "Porte de la Chapelle", "Opéra Garnier", "Sacré Coeur"]

for i in tqdm(range(len(places))) : 
    print(places[i])
    print(count_amenities2(places[i]))
    print(' ')
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Gare du Nord
# /home/onyxia/work/BATO-MOUCHE-Stat-App/fonctions.py:91: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   gdf_pois["center"]=gdf_pois.centroid
#            amenity how many
# 0       restaurant    976.0
# 1  culture and art     40.0
# 2        education    101.0
# 3            total   1117.0
#
# Tour Eiffel
# /home/onyxia/work/BATO-MOUCHE-Stat-App/fonctions.py:91: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   gdf_pois["center"]=gdf_pois.centroid
#            amenity how many
# 0       restaurant    326.0
# 1  culture and art     16.0
# 2        education     70.0
# 3            total    412.0
#
# Place de la Bastille
# ...

# %%
from palettable.colorbrewer.qualitative import Pastel1_7
composition_chart("Gare du Nord")
# Out:
# /home/onyxia/work/BATO-MOUCHE-Stat-App/fonctions.py:37: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   gdf_pois["center"]=gdf_pois.centroid
# /home/onyxia/work/BATO-MOUCHE-Stat-App/fonctions.py:37: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   gdf_pois["center"]=gdf_pois.centroid
# /home/onyxia/work/BATO-MOUCHE-Stat-App/fonctions.py:37: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   gdf_pois["center"]=gdf_pois.centroid
# ...
