# %%
import os
os.environ['USE_PYGEOS'] = '0'
import helpers as hs
from importlib import reload
# Out:
# --- Import helpers ---

# %% [markdown]
# # Données descriptives pour  des quartiers choisis

# %% [markdown]
# Explication et définition des catégories

# %% [markdown]
# # Création de la base  de données

# %% [markdown]
# ## Création des données aggrégées sur la grille INSPIRE 200X200m
# On part des données OSM cad une liste de points avec coordonnées et infos et on veut obtenir une liste des carrés INSPIRE avec le total des catégories par carré.

# %%
filosofi_file = "data/Filosofi2015_carreaux_200m_paris.gpkg"
pgdf = hs.get_POI_cat_on_INSPIRE_grid(filosofi_file)
# Out:
# c:\Users\leopo\OneDrive - GENES\StatApp\BATO-MOUCHE-Stat-App\helpers\scrapping.py:188: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   gdf_pois["center"]=gdf_pois.centroid

# %%
hs.folium_grid_cat_plot(pgdf,"nb restaurant")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_45bce7383a94101862c08c18ac5c1d79 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_45bce7383a94101862c08c18ac5c1d79&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_45bce7383a94101862c08c18ac5c1d79 = L.map(
#                 &quot;map_45bce7383a94101862c08c18ac5c1d79&quot;,
#                 {
#                     center: [48.85341, 2.3488],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12.1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_911fece0d26b8fd246be073ed2dbc38d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_45bce7383a94101862c08c18ac5c1d79);
#
#
#         function geo_json_48897b16408d439c89fcaf38b851a82f_styler(feature) {
#             switch(feature.id) {
#                 case &quot;1&quot;: case &quot;15&quot;: case &quot;24&quot;: case &quot;31&quot;: case &quot;32&quot;: case &quot;69&quot;: case &quot;81&quot;: case &quot;110&quot;: case &quot;120&quot;: case &quot;134&quot;: case &quot;135&quot;: case &quot;149&quot;: case &quot;150&quot;: case &quot;204&quot;: case &quot;223&quot;: case &quot;235&quot;: case &quot;268&quot;: case &quot;275&quot;: case &quot;282&quot;: case &quot;283&quot;: case &quot;284&quot;: case &quot;321&quot;: case &quot;327&quot;: case &quot;344&quot;: case &quot;359&quot;: case &quot;360&quot;: case &quot;370&quot;: case &quot;388&quot;: case &quot;398&quot;: case &quot;409&quot;: case &quot;424&quot;: case &quot;484&quot;: case &quot;493&quot;: case &quot;494&quot;: case &quot;530&quot;: case &quot;555&quot;: case &quot;583&quot;: case &quot;641&quot;: case &quot;642&quot;: case &quot;653&quot;: case &quot;654&quot;: case &quot;669&quot;: case &quot;686&quot;: case &quot;707&quot;: case &quot;717&quot;: case &quot;735&quot;: case &quot;737&quot;: case &quot;761&quot;: case &quot;775&quot;: case &quot;782&quot;: case &quot;799&quot;: case &quot;806&quot;: case &quot;822&quot;: case &quot;824&quot;: case &quot;910&quot;: case &quot;922&quot;: case &quot;932&quot;: case &quot;976&quot;: case &quot;991&quot;: case &quot;1002&quot;: case &quot;1013&quot;: case &quot;1045&quot;: case &quot;1055&quot;: case &quot;1056&quot;: case &quot;1064&quot;: case &quot;1067&quot;: case &quot;1075&quot;: case &quot;1099&quot;: case &quot;1134&quot;: case &quot;1139&quot;: case &quot;1153&quot;: case &quot;1165&quot;: case &quot;1193&quot;: case &quot;1196&quot;: case &quot;1197&quot;: case &quot;1200&quot;: case &quot;1203&quot;: case &quot;1219&quot;: case &quot;1221&quot;: case &quot;1226&quot;: case &quot;1235&quot;: case &quot;1252&quot;: case &quot;1255&quot;: case &quot;1291&quot;: case &quot;1294&quot;: case &quot;1310&quot;: case &quot;1338&quot;: case &quot;1353&quot;: case &quot;1374&quot;: case &quot;1392&quot;: case &quot;1394&quot;: case &quot;1407&quot;: case &quot;1411&quot;: case &quot;1418&quot;: case &quot;1419&quot;: case &quot;1437&quot;: case &quot;1442&quot;: case &quot;1449&quot;: case &quot;1459&quot;: case &quot;1462&quot;: case &quot;1466&quot;: case &quot;1472&quot;: case &quot;1479&quot;: case &quot;1491&quot;: case &quot;1514&quot;: case &quot;1525&quot;: case &quot;1541&quot;: case &quot;1581&quot;: case &quot;1583&quot;: case &quot;1617&quot;: case &quot;1654&quot;: case &quot;1693&quot;: case &quot;1712&quot;: case &quot;1719&quot;: case &quot;1724&quot;: case &quot;1736&quot;: case &quot;1738&quot;: case &quot;1739&quot;: case &quot;1796&quot;: case &quot;1800&quot;: case &quot;1808&quot;: case &quot;1819&quot;: case &quot;1825&quot;: c

# %% [markdown]
# ## Calcul des indices d'accessibilité

# %% [markdown]
# # Analyses

# %% [markdown]
# ## Régression

# %% [markdown]
# ## Clusterisation
